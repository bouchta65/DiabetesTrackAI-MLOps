# %%
import pandas as pd
file = r"B:\Machine Learning\Sprint1\YC2_DiabetesTrackAI\data\Clustered_Data.csv"

content = pd.read_csv(file)

content.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.862288       0.054979       0.644753  0.838548  0.165148
# 1    -0.844885 -1.207101      -0.439758       0.011894 -0.889580 -0.852384
# 2     1.233880  2.011949      -0.614571       0.054084  1.839357 -1.332078
# 3    -0.844885 -1.075711      -0.439758      -0.620966 -0.475688 -0.634341
# 4    -1.141852  0.500966      -3.272736       0.644753  0.478673  1.546085
#
#    DiabetesPedigreeFunction       Age  Cluster
# 0                  0.612059  1.425995        0
# 1                 -0.324994 -0.190672        1
# 2                  0.749586 -0.105584        0
# 3                 -1.063014 -1.041549        1
# 4                  4.158488 -0.020496        0

# %%
content.groupby("Cluster").mean()
# Out:
#          Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin  \
# Cluster
# 0           0.413157  0.681864       0.461416       0.517877  0.636883
# 1          -0.340536 -0.562011      -0.380312      -0.426849 -0.524937
#
#               BMI  DiabetesPedigreeFunction       Age
# Cluster
# 0        0.522060                  0.132541  0.535884
# 1       -0.430296                 -0.109244 -0.441691

# %%
count = content["Cluster"].value_counts()

count.plot(kind='bar')
# Out:
# <Axes: xlabel='Cluster'>

# %%
import numpy as np
content["Age+BMI"] = np.where(content["Age"]>0.5,content["BMI"]+content["Age"],content["Age"])

content.head(10)
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.862288       0.054979       0.644753  0.838548  0.165148
# 1    -0.844885 -1.207101      -0.439758       0.011894 -0.889580 -0.852384
# 2     1.233880  2.011949      -0.614571       0.054084  1.839357 -1.332078
# 3    -0.844885 -1.075711      -0.439758      -0.620966 -0.475688 -0.634341
# 4    -1.141852  0.500966      -3.272736       0.644753  0.478673  1.546085
# 5     0.342981 -0.188830       0.210891      -1.296017 -0.594987 -0.997746
# 6    -0.250952 -1.437033      -2.013763       0.328324 -0.583779 -0.212792
# 7     1.827813 -0.221677       0.481334       0.011894  0.099133  0.412263
# 8    -0.547919  2.471813      -0.105264       1.699520  2.415574 -0.285473
# 9     1.233880  0.106797       1.694655       1.298709  0.764326  0.348304
#
#    DiabetesPedigreeFunction       Age  Cluster   Age+BMI
# 0                  0.612059  1.425995        0  1.591144
# ...
